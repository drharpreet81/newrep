# %% [markdown]
# <a href="https://colab.research.google.com/github/drharpreet81/newrep/blob/main/Rich_Text_Documentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)

# %% [markdown]
# ### **how to enter the Text**
#
# 1.   Simple Data
# 2.   link of any site
# 3.   Image upload

# %% [markdown]
# [Search Site](https://www.google.com/)
# [Connect to Email](https://mail.google.com/mail/u/0/#inbox)
